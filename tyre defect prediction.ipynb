# %% [markdown]
# ## TIRE BUILDING DEFECT PREDICTION

# %%
## IMPORTING ALL LIBRARIES AND DATA FILE IN JUPYTER NOTEBOOK

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
data = pd.read_csv('fsob1.csv')

# %%
data.head()
# Out:
#    GT BARCODE  BREAKER2 WIDTH MEASURED  BREAKER2 WIDTH SETPOINT   \
# 0  8307556022               152.350006                       152
# 1  8307556023               152.350006                       152
# 2  8307556024               151.990005                       152
# 3  8307556025               152.270004                       152
# 4  8307556026               152.630005                       152
#
#    BREAKER2 LENGTH MEASURED     BREAKER2 LENGTH SETPOINT     \
# 0                  1988.300049                         1990
# 1                  1991.599976                         1990
# 2                  1989.800049                         1990
# 3                  1991.000000                         1990
# 4                  1993.300049                         1990
#
#    BREAKER2 LE ANGLE MEASURED    BREAKER2 TE ANGLE MEASURED  \
# 0                      0.000000                   23.969999
# 1                     23.730000                   23.699999
# ...

# %% [markdown]
# ## DATA CLEANING AND INFO

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13032 entries, 0 to 13031
# Data columns (total 85 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   GT BARCODE                            13032 non-null  int64
#  1   BREAKER2 WIDTH MEASURED               13032 non-null  float64
#  2   BREAKER2 WIDTH SETPOINT               13032 non-null  int64
#  3   BREAKER2 LENGTH MEASURED              13032 non-null  float64
#  4   BREAKER2 LENGTH SETPOINT              13032 non-null  int64
#  5   BREAKER2 LE ANGLE MEASURED            13032 non-null  float64
#  6   BREAKER2 TE ANGLE MEASURED            13032 non-null  float64
#  7   BREAKER2 ANGLE SETPOINT               13032 non-null  int64
#  8   BREAKER2 POS WIDTH OK                 13032 non-null  int64
#  9   BREAKER2 MEAS LENGTH AXIS             13032 non-null  float64
#  10  BREAKER2 USE VVS LENGTH               13032 non-null  int64
# ...

# %%
data.shape
# Out:
# (13032, 85)

# %%
data.isnull().sum()
# Out:
# GT BARCODE                     0
# BREAKER2 WIDTH MEASURED        0
# BREAKER2 WIDTH SETPOINT        0
# BREAKER2 LENGTH MEASURED       0
# BREAKER2 LENGTH SETPOINT       0
#                               ..
# P2 RIGHT                       2
# P1 LEFT                        2
# P1 MID                         2
# P1 RIGHT                       2
# target                         0
# Length: 85, dtype: int64

# %%
data.fillna('na')
# Out:
#        GT BARCODE  BREAKER2 WIDTH MEASURED  BREAKER2 WIDTH SETPOINT   \
# 0      8307556022               152.350006                       152
# 1      8307556023               152.350006                       152
# 2      8307556024               151.990005                       152
# 3      8307556025               152.270004                       152
# 4      8307556026               152.630005                       152
# ...           ...                      ...                       ...
# 13027  8307823539               151.270004                       152
# 13028  8307823540               151.479996                       152
# 13029  8307823541               151.839996                       152
# 13030  8307823542               151.639999                       152
# 13031  8307823543               151.839996                       152
#
#        BREAKER2 LENGTH MEASURED     BREAKER2 LENGTH SETPOINT     \
# 0                      1988.300049                         1990
# ...

# %%
data = data.dropna()

# %%
data.isnull().sum()
# Out:
# GT BARCODE                     0
# BREAKER2 WIDTH MEASURED        0
# BREAKER2 WIDTH SETPOINT        0
# BREAKER2 LENGTH MEASURED       0
# BREAKER2 LENGTH SETPOINT       0
#                               ..
# P2 RIGHT                       0
# P1 LEFT                        0
# P1 MID                         0
# P1 RIGHT                       0
# target                         0
# Length: 85, dtype: int64

# %%
data.describe()
# Out:
#          GT BARCODE  BREAKER2 WIDTH MEASURED  BREAKER2 WIDTH SETPOINT   \
# count  1.303000e+04             13030.000000                   13030.0
# mean   8.307722e+09               152.170376                     152.0
# std    7.352716e+04                 2.459932                       0.0
# min    8.307556e+09                 0.000000                     152.0
# 25%    8.307693e+09               151.979996                     152.0
# 50%    8.307744e+09               152.199997                     152.0
# 75%    8.307772e+09               152.419998                     152.0
# max    8.307824e+09               157.479996                     152.0
#
#        BREAKER2 LENGTH MEASURED     BREAKER2 LENGTH SETPOINT     \
# count                 13030.000000                      13030.0
# mean                   1983.234259                       1990.0
# std                     107.278482                          0.0
# min                       0.000000                       1990.0
# ...

# %% [markdown]
# ## Train and Split data

# %%
x = data.drop(['target','GT BARCODE'], axis =1)

# %%
x
# Out:
#        BREAKER2 WIDTH MEASURED  BREAKER2 WIDTH SETPOINT   \
# 0                   152.350006                       152
# 1                   152.350006                       152
# 2                   151.990005                       152
# 3                   152.270004                       152
# 4                   152.630005                       152
# ...                        ...                       ...
# 13027               151.270004                       152
# 13028               151.479996                       152
# 13029               151.839996                       152
# 13030               151.639999                       152
# 13031               151.839996                       152
#
#        BREAKER2 LENGTH MEASURED     BREAKER2 LENGTH SETPOINT     \
# 0                      1988.300049                         1990
# 1                      1991.599976                         1990
# 2                      1989.800049                         1990
# ...

# %%
y = data['target']

# %%
y.value_counts()
# Out:
# 0    12978
# 2       52
# Name: target, dtype: int64

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,random_state=14, test_size =0.3)

# %%
print(x_train.shape,x_test.shape,y_train.shape,y_test.shape)
# Out:
# (9121, 83) (3909, 83) (9121,) (3909,)

# %% [markdown]
# ## model selection

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier()

# %%
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
pred = model.predict(x_test)

# %% [markdown]
# ## Model accuracy score

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy = accuracy_score(pred,y_test)

# %%
accuracy
# Out:
# 0.9976976208749041

# %%
input = (152.3500061,152,1990.800049,1990,23.68999863,23.84000015,24,1,1991.854736,0,80,26.25799942,61.39300156,166.3200073,164,1978.5,1983,24.12999916,24.12999916,24,1,1982.71936,0,260,26.72900009,61.43000031,290,214.9900055,212,2013.247803,2015,1,18.8029995,61.50400162,730.3061523,733,1213.137939,1211,-0.761187196,190,170,12.75599957,68.47699738,1228.342529,1228,564,210,1,2,0,6.857999802,1230.348145,1229,508,90,2,2,0,27.55900002,2,2,16,0.599511623,0.599511623,0.406593412,0.406593412,0.186813191,0.186813191,1.002442002,1.002442002,9.045999527,270,0.7773405,30,110,0.05,-0.2,5.682307,11.86087,5.618737,6.62324,6.621703,7.078686)
input = np.asarray(input)

input1 = input.reshape(1,-1)

model.predict(input1)
# Out:
# C:\Users\91772\anconda\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# array([0], dtype=int64)
